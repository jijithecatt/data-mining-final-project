# %% [markdown]
# <a href="https://drive.google.com/drive/folders/176VLvhLVMz4-ZFKh1uHpCijZJfQWd-6w?usp=sharing">Link to the dataset</a>

# %% [markdown]
# <blockquote>
# Utility function declaration
# </blocquote>

# %%
# input: Pandas DataFrame named data
# output: print a summary of the passing Pandas DataFrame 
def printSummary(data):
    print('Number of objects = {}'.format(data.shape[0]))
    print('Number of attributes = {}'.format(data.shape[1]))
    print('   | Column                      | Missing values | Infinity values')
    print('-------------------------------------------------------------------')
    i = 0
    for col_label in data.columns:
        print('{0:2d} | {1:27s} | {2:14d} | {3:15d}'.format(i, col_label, data[col_label].isnull().sum(), data[col_label].isin([np.inf]).sum()))
        i = i + 1
    print('-------------------------------------------------------------------')

# %% [markdown]
# # 1. Data cleaning

# %%
import pandas as pd
import numpy as np
import warnings
# suppress the warning caused by setting the first column as index column
warnings.simplefilter(action='ignore', category=FutureWarning) 
data = pd.read_csv('cic2017-ddos-data.csv', index_col=0, header=0)
# dataset contains infinite values in some columns
data = data.replace('inf', np.inf)

print('Dataset before cleaning:')
printSummary(data)
print('Label column information:')
print(data.loc[:, 'Label'].describe())
# Out:
# Dataset before cleaning:
# Number of objects = 755663
# Number of attributes = 85
#    | Column                      | Missing values | Infinity values
# -------------------------------------------------------------------
#  0 | Flow ID                     |              0 |               0
#  1 | Source IP                   |              0 |               0
#  2 | Source Port                 |              0 |               0
#  3 | Destination IP              |              0 |               0
#  4 | Destination Port            |              0 |               0
#  5 | Protocol                    |              0 |               0
#  6 | Timestamp                   |              0 |               0
#  7 | Flow Duration               |              0 |               0
#  8 | Total Fwd Packets           |              0 |               0
#  9 | Total Backward Packets      |              0 |               0
# 10 | Total Length of Fwd Packets |              0 |               0
# 11 | Total Length of Bwd Packets |              0 |               0
# 12 | Fwd Packet Length Max       |              0 |               0
# 13 | Fwd Packet Length Min       |              0 |               0
# 14 | Fwd Packet Length Mean      |              0 |               0
# 15 | Fwd Packet Length Std       |              0 |               0
# 16 | Bwd Packet Length Max       |              0 |               0
# 17 | Bwd Packet Length Min       |              0 |               0
# 18 | Bwd Packet Length Mean      |              0 |               0
# 19 | Bwd Packet Length Std       |              0 |               0
# 20 | Flow Bytes/s                |             68 |             403
# 21 | Flow Packets/s              |              0 |             471
# 22 | Flow IAT Mean               |              0 |               0
# 23 | Flow IAT Std                |              0 |               0
# 24 | Flow IAT Max                |              0 |               0
# 25 | Flow IAT Min                |              0 |               0
# 26 | Fwd IAT Total               |              0 |               0
# 27 | Fwd IAT Mean                |              0 |               0
# 28 | Fwd IAT Std                 |              0 |               0
# 29 | Fwd IAT Max                 |              0 |               0
# 30 | Fwd IAT Min                 |              0 |               0
# 31 | Bwd IAT Total               |              0 |               0
# 32 | Bwd IAT Mean                |              0 |               0
# 33 | Bwd IAT Std                 |              0 |               0
# 34 | Bwd IAT Max                 |              0 |               0
# 35 | Bwd IAT Min                 |              0 |               0
# 36 | Fwd PSH Flags               |              0 |               0
# 37 | Bwd PSH Flags               |              0 |               0
# 38 | Fwd URG Flags               |              0 |               0
# 39 | Bwd URG Flags               |              0 |               0
# 40 | Fwd Header Length           |              0 |               0
# 41 | Bwd Header Length           |              0 |               0
# 42 | Fwd Packets/s               |              0 |               0
# 43 | Bwd Packets/s               |              0 |               0
# 44 | Min Packet Length           |              0 |               0
# 45 | Max Packet Length           |              0 |               0
# 46 | Packet Length Mean          |              0 |               0
# 47 | Packet Length Std           |              0 |               0
# 48 | Packet Length Variance      |              0 |               0
# 49 | FIN Flag Count              |              0 |               0
# 50 | SYN Flag Count              |              0 |               0
# 51 | RST Flag Count              |              0 |               0
# 52 | PSH Flag Count              |              0 |               0
# 53 | ACK Flag Count              |              0 |               0
# 54 | URG Flag Count              |              0 |               0
# 55 | CWE Flag Count              |              0 |               0
# 56 | ECE Flag Count              |              0 |               0
# 57 | Down/Up Ratio               |              0 |               0
# 58 | Average Packet Size         |              0 |               0
# 59 | Avg Fwd Segment Size        |              0 |               0
# 60 | Avg Bwd Segment Size        |              0 |               0
# 61 | Fwd Header Length - dupl    |              0 |               0
# 62 | Fwd Avg Bytes/Bulk          |              0 |               0
# 63 | Fwd Avg Packets/Bulk        |              0 |               0
# 64 | Fwd Avg Bulk Rate           |              0 |               0
# 65 | Bwd Avg Bytes/Bulk          |              0 |               0
# 66 | Bwd Avg Packets/Bulk        |              0 |               0
# 67 | Bwd Avg Bulk Rate           |              0 |               0
# 68 | Subflow Fwd Packets         |              0 |               0
# 69 | Subflow Fwd Bytes           |              0 |               0
# 70 | Subflow Bwd Packets         |              0 |               0
# 71 | Subflow Bwd Bytes           |              0 |               0
# 72 | Init_Win_bytes_forward      |              0 |               0
# 73 | Init_Win_bytes_backward     |              0 |               0
# 74 | Act_data_pkt_fwd            |              0 |               0
# 75 | Min_seg_size_forward        |              0 |               0
# 76 | Active Mean                 |              0 |               0
# 77 | Active Std                  |              0 |               0
# 78 | Active Max                  |              0 |               0
# 79 | Active Min                  |              0 |               0
# 80 | Idle Mean                   |              0 |               0
# 81 | Idle Std                    |              0 |               0
# 82 | Idle Max                    |              0 |               0
# 83 | Idle Min                    |              0 |               0
# 84 | Label                       |              0 |               0
# -------------------------------------------------------------------
# Label column information:
# count     755663
# unique         2
# top       BENIGN
# freq      627636
# Name: Label, dtype: object

# %%
data = data.replace(np.nan, np.inf)
data['Flow Bytes/s'].replace(np.inf, data['Flow Bytes/s'].median(), inplace=True)
data['Flow Packets/s'].replace(np.inf, data['Flow Packets/s'].median(), inplace=True)

print('Dataset after cleaning:')
printSummary(data)
# Out:
# Dataset after cleaning:
# Number of objects = 755663
# Number of attributes = 85
#    | Column                      | Missing values | Infinity values
# -------------------------------------------------------------------
#  0 | Flow ID                     |              0 |               0
#  1 | Source IP                   |              0 |               0
#  2 | Source Port                 |              0 |               0
#  3 | Destination IP              |              0 |               0
#  4 | Destination Port            |              0 |               0
#  5 | Protocol                    |              0 |               0
#  6 | Timestamp                   |              0 |               0
#  7 | Flow Duration               |              0 |               0
#  8 | Total Fwd Packets           |              0 |               0
#  9 | Total Backward Packets      |              0 |               0
# 10 | Total Length of Fwd Packets |              0 |               0
# 11 | Total Length of Bwd Packets |              0 |               0
# 12 | Fwd Packet Length Max       |              0 |               0
# 13 | Fwd Packet Length Min       |              0 |               0
# 14 | Fwd Packet Length Mean      |              0 |               0
# 15 | Fwd Packet Length Std       |              0 |               0
# 16 | Bwd Packet Length Max       |              0 |               0
# 17 | Bwd Packet Length Min       |              0 |               0
# 18 | Bwd Packet Length Mean      |              0 |               0
# 19 | Bwd Packet Length Std       |              0 |               0
# 20 | Flow Bytes/s                |              0 |               0
# 21 | Flow Packets/s              |              0 |               0
# 22 | Flow IAT Mean               |              0 |               0
# 23 | Flow IAT Std                |              0 |               0
# 24 | Flow IAT Max                |              0 |               0
# 25 | Flow IAT Min                |              0 |               0
# 26 | Fwd IAT Total               |              0 |               0
# 27 | Fwd IAT Mean                |              0 |               0
# 28 | Fwd IAT Std                 |              0 |               0
# 29 | Fwd IAT Max                 |              0 |               0
# 30 | Fwd IAT Min                 |              0 |               0
# 31 | Bwd IAT Total               |              0 |               0
# 32 | Bwd IAT Mean                |              0 |               0
# 33 | Bwd IAT Std                 |              0 |               0
# 34 | Bwd IAT Max                 |              0 |               0
# 35 | Bwd IAT Min                 |              0 |               0
# 36 | Fwd PSH Flags               |              0 |               0
# 37 | Bwd PSH Flags               |              0 |               0
# 38 | Fwd URG Flags               |              0 |               0
# 39 | Bwd URG Flags               |              0 |               0
# 40 | Fwd Header Length           |              0 |               0
# 41 | Bwd Header Length           |              0 |               0
# 42 | Fwd Packets/s               |              0 |               0
# 43 | Bwd Packets/s               |              0 |               0
# 44 | Min Packet Length           |              0 |               0
# 45 | Max Packet Length           |              0 |               0
# 46 | Packet Length Mean          |              0 |               0
# 47 | Packet Length Std           |              0 |               0
# 48 | Packet Length Variance      |              0 |               0
# 49 | FIN Flag Count              |              0 |               0
# 50 | SYN Flag Count              |              0 |               0
# 51 | RST Flag Count              |              0 |               0
# 52 | PSH Flag Count              |              0 |               0
# 53 | ACK Flag Count              |              0 |               0
# 54 | URG Flag Count              |              0 |               0
# 55 | CWE Flag Count              |              0 |               0
# 56 | ECE Flag Count              |              0 |               0
# 57 | Down/Up Ratio               |              0 |               0
# 58 | Average Packet Size         |              0 |               0
# 59 | Avg Fwd Segment Size        |              0 |               0
# 60 | Avg Bwd Segment Size        |              0 |               0
# 61 | Fwd Header Length - dupl    |              0 |               0
# 62 | Fwd Avg Bytes/Bulk          |              0 |               0
# 63 | Fwd Avg Packets/Bulk        |              0 |               0
# 64 | Fwd Avg Bulk Rate           |              0 |               0
# 65 | Bwd Avg Bytes/Bulk          |              0 |               0
# 66 | Bwd Avg Packets/Bulk        |              0 |               0
# 67 | Bwd Avg Bulk Rate           |              0 |               0
# 68 | Subflow Fwd Packets         |              0 |               0
# 69 | Subflow Fwd Bytes           |              0 |               0
# 70 | Subflow Bwd Packets         |              0 |               0
# 71 | Subflow Bwd Bytes           |              0 |               0
# 72 | Init_Win_bytes_forward      |              0 |               0
# 73 | Init_Win_bytes_backward     |              0 |               0
# 74 | Act_data_pkt_fwd            |              0 |               0
# 75 | Min_seg_size_forward        |              0 |               0
# 76 | Active Mean                 |              0 |               0
# 77 | Active Std                  |              0 |               0
# 78 | Active Max                  |              0 |               0
# 79 | Active Min                  |              0 |               0
# 80 | Idle Mean                   |              0 |               0
# 81 | Idle Std                    |              0 |               0
# 82 | Idle Max                    |              0 |               0
# 83 | Idle Min                    |              0 |               0
# 84 | Label                       |              0 |               0
# -------------------------------------------------------------------

# %% [markdown]
# # 2. Data preprocessing

# %%
print('Number of matching values of two columns \"Fwd Header Length\" and \"Fwd Header Length - dupl\": {}'.format(data['Fwd Header Length'].eq(data['Fwd Header Length - dupl']).sum()))
# drop two duplicated columns
data = data.drop(['Fwd Header Length - dupl'], axis=1)
print('Dataset after dropping duplicated column: ')
print('Number of instances = {}'.format(data.shape[0]))
print('Number of attributes = {}'.format(data.shape[1]))
# Out:
# Number of matching values of two columns "Fwd Header Length" and "Fwd Header Length - dupl": 755663
# Dataset after dropping duplicated column:
# Number of instances = 755663
# Number of attributes = 84

# %%
from sklearn.decomposition import PCA

numInstances = data.shape[0]
numComponents = 10
pca = PCA(n_components=numComponents)
pca.fit(data.loc[:, 'Flow Duration':'Idle Min'])

projected = pca.transform(data.loc[:, 'Flow Duration':'Idle Min'])
projected = pd.DataFrame(projected,columns=['PC1','PC2','PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10'], index=range(numInstances))
projected.head(20)
# Out:
#              PC1            PC2           PC3            PC4            PC5  \
# 0  -2.408698e+07  535254.149989  1.453473e+06  902919.373947 -355285.291540
# 1  -2.418045e+07  590354.229422  1.046009e+07  855603.211236 -344858.757347
# 2  -2.418045e+07  590354.229422  1.046009e+07  855603.211236 -344858.757347
# 3  -2.418045e+07  590354.229422  1.046009e+07  855603.211236 -344858.757347
# 4  -2.409737e+07  541376.130440  2.454209e+06  897662.006552 -354127.868235
# 5  -2.418045e+07  590354.237739  1.046009e+07  855603.212160 -344858.761112
# 6  -2.418045e+07  590354.237739  1.046009e+07  855603.212160 -344858.761112
# 7  -2.418045e+07  590354.237739  1.046009e+07  855603.212160 -344858.761112
# 8  -2.406981e+07  525823.842929 -7.425198e+04  910603.316790 -357069.962224
# 9  -2.409601e+07  547006.832824  2.682668e+06  888217.027011 -355215.754222
# 10 -2.410597e+07  556074.801553  3.779583e+06  877774.321106 -354659.016027
# 11 -2.416288e+07  589494.190021  9.197864e+06  848896.859728 -348106.011254
# 12 -2.407655e+07  529122.829595  4.523256e+05  908157.146792 -356428.834125
# 13 -2.410845e+07  557447.706955  4.008779e+06  876425.048263 -354381.606394
# 14 -2.402147e+07  520079.987079 -1.011126e+06  903540.684357 -363378.192816
# 15 -2.406438e+07  522786.826792 -5.584987e+05  913243.045364 -357670.960491
# 16 -2.409455e+07  545711.413497  2.528255e+06  889665.744586 -355284.489656
# 17 -2.410777e+07  556970.618637  3.928953e+06  877346.585551 -354469.625589
# 18 -2.406962e+07  525725.599720 -9.100741e+04  910685.332855 -357085.610404
# 19 -2.408070e+07  531570.081498  8.525374e+05  906050.893911 -355962.152569
#
#               PC6            PC7          PC8          PC9           PC10
# 0   171524.876162 -327207.474978 -4822.703278  -770.486758 -124251.621008
# 1   166728.122665 -320211.333373 -6069.926378 -1159.471051 -123116.748762
# 2   166728.122665 -320211.333373 -6069.926378 -1159.471051 -123116.748762
# 3   166728.122665 -320211.333373 -6069.926378 -1159.471051 -123116.748762
# 4   170991.814487 -326431.142567 -4961.288699  -813.707034 -124125.444506
# 5   166728.129348 -320211.360792 -6069.926280 -1159.470533 -123116.732972
# 6   166728.129348 -320211.360792 -6069.926280 -1159.470533 -123116.732972
# 7   166728.129348 -320211.360792 -6069.926280 -1159.470533 -123116.732972
# 8   172771.801627 -328173.231498 -3890.344035  -922.235421 -124387.557966
# 9   175465.325020 -331051.054511  2589.154412 -2147.367232 -138906.342783
# 10  177224.590639 -333252.633809  4249.933855 -2920.569909 -147815.404565
# 11  173926.523467 -328727.637299  3338.714681 -3477.158601 -146515.158590
# 12  172046.312485 -327924.595400 -4669.020277  -737.117764 -124276.311532
# 13  177070.610157 -333251.729441  4304.613281 -2966.488884 -148152.116174
# 14  190923.176507 -329369.166617  8618.288856 -2325.531475 -143351.242748
# 15  173168.474354 -328458.504883 -3940.473202  -871.045646 -124299.810251
# 16  175222.423964 -330740.237230  2184.804892 -2050.323643 -137676.650823
# 17  177023.002633 -332914.463681  3732.064172 -2876.467925 -147143.882161
# 18  172782.485731 -328185.790408 -3888.461152  -920.602195 -124387.936420
# 19  171830.893992 -327602.374399 -4722.959089  -760.310595 -124204.915969

# %%
from sklearn.model_selection import train_test_split

new = pd.concat([data.iloc[:, 0:7], projected, data.iloc[:, 83]], axis=1)
print('Dataset after performing PCA:')
printSummary(new)

y = new.loc[:, 'Label']
x = new.drop(['Label'], axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)
print('Number of objects in training set: {}'.format(x_train.shape[0]))
print('Number of objects in testing set:  {}'.format(x_test.shape[0]))
# Out:
# Dataset after performing PCA:
# Number of objects = 755663
# Number of attributes = 18
#    | Column                      | Missing values | Infinity values
# -------------------------------------------------------------------
#  0 | Flow ID                     |              0 |               0
#  1 | Source IP                   |              0 |               0
#  2 | Source Port                 |              0 |               0
#  3 | Destination IP              |              0 |               0
#  4 | Destination Port            |              0 |               0
#  5 | Protocol                    |              0 |               0
#  6 | Timestamp                   |              0 |               0
#  7 | PC1                         |              0 |               0
#  8 | PC2                         |              0 |               0
#  9 | PC3                         |              0 |               0
# 10 | PC4                         |              0 |               0
# 11 | PC5                         |              0 |               0
# 12 | PC6                         |              0 |               0
# 13 | PC7                         |              0 |               0
# 14 | PC8                         |              0 |               0
# 15 | PC9                         |              0 |               0
# 16 | PC10                        |              0 |               0
# 17 | Label                       |              0 |               0
# -------------------------------------------------------------------
# Number of objects in training set: 528964
# Number of objects in testing set:  226699
